# %%
# importing libraries
import numpy as np
import pandas as pd
from pathlib import Path
import hvplot.pandas
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
import time

# %%
all_values = pd.read_csv(Path("Resources/all_values.csv"))
all_values['date'] = pd.to_datetime(all_values['date'], format='%Y-%m')
all_values.set_index('date', inplace=True)
all_values.index = all_values.index.strftime('%Y-%m')

# %%
y = all_values["Composite"]

# %%
X = all_values.drop(columns = "Composite")

# %%
y
# Out:
# date
# 2008-06    319000.0
# 2008-07    317800.0
# 2008-08    316800.0
# 2008-09    315900.0
# 2008-10    312700.0
#              ...
# 2022-12    874300.0
# 2023-01    859300.0
# 2023-02    853200.0
# 2023-03    858500.0
# 2023-04    877400.0
# Name: Composite, Length: 179, dtype: float64

# %%
X
# Out:
#          Lumber       Wood        XHB        ITB  All-items 8   Food  Shelter  \
# date
# 2008-06  254.96  48.860001  20.260000  17.610001        114.9  115.2    122.3
# 2008-07  261.80  48.529999  18.690001  16.480000        115.4  116.0    123.3
# 2008-08  270.10  49.169998  19.730000  16.530001        115.4  116.8    123.8
# 2008-09  240.70  49.919998  22.370001  19.750000        115.5  118.0    123.1
# 2008-10  199.50  44.180000  20.110001  18.150000        114.7  118.5    123.2
# ...         ...        ...        ...        ...          ...    ...      ...
# 2022-12  425.60  76.900002  63.290001  62.840000        154.3  178.7    167.8
# 2023-01  527.70  78.440002  69.449997  69.570000        154.7  180.4    168.0
# 2023-02  510.40  79.949997  72.269997  73.209999        154.9  181.2    168.3
# 2023-03  452.40  75.389999  68.809998  70.290001        155.3  182.0    168.9
# 2023-04  424.60  72.980003  70.919998  75.790001        156.2  182.9    169.9
#
#          Household operations, furnishings and equipment  \
# date
# 2008-06                                            104.3
# 2008-07                                            104.5
# 2008-08                                            104.5
# 2008-09                                            105.4
# 2008-10                                            105.2
# ...                                                  ...
# 2022-12                                            132.7
# 2023-01                                            132.2
# 2023-02                                            133.3
# 2023-03                                            133.2
# 2023-04                                            133.4
#
#          Clothing and footwear  Transportation  Health and personal care  \
# date
# 2008-06                   94.0           124.0                     108.3
# 2008-07                   94.8           124.0                     108.4
# 2008-08                   94.3           122.4                     109.3
# 2008-09                   94.0           122.3                     109.2
# 2008-10                   92.7           118.3                     109.3
# ...                        ...             ...                       ...
# 2022-12                   96.1           168.6                     142.0
# 2023-01                   95.8           168.2                     142.7
# 2023-02                   96.6           166.9                     143.4
# 2023-03                   96.9           166.5                     144.2
# 2023-04                   96.7           168.3                     144.9
#
#          Recreation, education and reading  \
# date
# 2008-06                              102.3
# 2008-07                              102.2
# 2008-08                              102.5
# 2008-09                              102.4
# 2008-10                              102.2
# ...                                    ...
# 2022-12                              124.6
# 2023-01                              124.6
# 2023-02                              124.3
# 2023-03                              124.9
# 2023-04                              125.5
#
#          Alcoholic beverages, tobacco products and recreational cannabis  \
# date
# 2008-06                                              127.7
# 2008-07                                              127.6
# 2008-08                                              127.5
# 2008-09                                              128.0
# 2008-10                                              128.0
# ...                                                    ...
# 2022-12                                              185.2
# 2023-01                                              186.5
# 2023-02                                              187.4
# 2023-03                                              188.7
# 2023-04                                              189.1
#
#          All-items excluding food  All-items excluding food and energy
# date
# 2008-06                     114.9                                110.3
# 2008-07                     115.2                                110.4
# 2008-08                     115.0                                110.6
# 2008-09                     115.0                                110.6
# 2008-10                     113.9                                110.4
# ...                           ...                                  ...
# 2022-12                     149.8                                144.8
# 2023-01                     149.9                                145.0
# 2023-02                     150.1                                145.5
# 2023-03                     150.4                                146.0
# 2023-04                     151.3                                146.5
#
# [179 rows x 15 columns]
